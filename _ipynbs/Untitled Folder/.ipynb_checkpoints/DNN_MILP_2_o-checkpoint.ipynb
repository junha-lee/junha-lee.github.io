# %%
import pandas as pd
df1 = pd.read_csv('datasets/DAP/2017/jan_feb.csv')
df2 = pd.read_csv('datasets/DAP/2017/mar_apr.csv')
df3 = pd.read_csv('datasets/DAP/2017/may_jun.csv')
df4 = pd.read_csv('datasets/DAP/2017/july_august.csv')
df5 = pd.read_csv('datasets/DAP/2017/sep_oct.csv')
df6 = pd.read_csv('datasets/DAP/2017/nov_dec.csv')

df7 = pd.read_csv('datasets/DAP/2018/jan_feb.csv')
df8 = pd.read_csv('datasets/DAP/2018/mar_apr.csv')
df9 = pd.read_csv('datasets/DAP/2018/may_jun.csv')
df10 = pd.read_csv('datasets/DAP/2018/july_august.csv')
df11 = pd.read_csv('datasets/DAP/2018/sep_oct.csv')
df12 = pd.read_csv('datasets/DAP/2018/nov_dec.csv')

df13 = pd.read_csv('datasets/DAP/2019/jan_feb.csv')
df14 = pd.read_csv('datasets/DAP/2019/mar_apr.csv')
df15 = pd.read_csv('datasets/DAP/2019/may_jun.csv')
df16 = pd.read_csv('datasets/DAP/2019/july_august.csv')
df17 = pd.read_csv('datasets/DAP/2019/sep_oct.csv')
df18 = pd.read_csv('datasets/DAP/2019/nov_dec.csv')


frames =[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18]
three_year_prices = pd.concat(frames)

# %%
three_year_prices.info
# Out:
# <bound method DataFrame.info of                  DateTime  day_ahead_pricing (michigan_hub) (miso)
# 0     2017-01-01 00:00:00                                    24.36
# 1     2017-01-01 01:00:00                                    23.27
# 2     2017-01-01 02:00:00                                    22.57
# 3     2017-01-01 03:00:00                                    22.89
# 4     2017-01-01 04:00:00                                    22.38
# ...                   ...                                      ...
# 1459  2019-12-31 19:00:00                                    27.63
# 1460  2019-12-31 20:00:00                                    26.66
# 1461  2019-12-31 21:00:00                                    24.50
# 1462  2019-12-31 22:00:00                                    21.76
# 1463  2019-12-31 23:00:00                                    20.75
#
# [26280 rows x 2 columns]>

# %%
import numpy as np

three_year_prices.set_index("DateTime", inplace=True)
three_year_prices["day_ahead_pricing (michigan_hub) (miso)"] = three_year_prices["day_ahead_pricing (michigan_hub) (miso)"] / 10 # convert to cent/kwh
tempt = three_year_prices["day_ahead_pricing (michigan_hub) (miso)"].values
three_year_price = np.array(tempt).reshape(-1,1)
three_year_price.shape
# Out:
# (26280, 1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
three_year_prices["day_ahead_pricing (michigan_hub) (miso)"].plot(figsize=(20,5))
plt.show()

# %%
df = pd.read_csv('datasets/weather/temperature.csv')

# %%
df.set_index('datetime',inplace=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df["Detroit"].plot(figsize=(20,5))
plt.show()

# %%
selected_columns = df[["Detroit"]]
new_df=selected_columns.copy()
new_df.head()
# Out:
#                         Detroit
# datetime
# 2012-10-01 12:00:00         NaN
# 2012-10-01 13:00:00  284.030000
# 2012-10-01 14:00:00  284.069789
# 2012-10-01 15:00:00  284.173965
# 2012-10-01 16:00:00  284.278140

# %%
#T(°F) = T(K) × 9/5 - 459.67
new_df['Detroit'] = new_df['Detroit'] * 9 / 5 - 459.67
new_df.head()
# Out:
#                        Detroit
# datetime
# 2012-10-01 12:00:00        NaN
# 2012-10-01 13:00:00  51.584000
# 2012-10-01 14:00:00  51.655621
# 2012-10-01 15:00:00  51.843136
# 2012-10-01 16:00:00  52.030652

# %%
input_data = new_df.loc['2013-01-01 00:00:00':'2015-12-31 23:00:00',:]

# %%
training_data = input_data.values
training_data.shape
# Out:
# (26280, 1)

# %%
three_year_price[0:24].ravel()
# Out:
# array([2.436, 2.327, 2.257, 2.289, 2.238, 2.298, 2.291, 2.405, 2.499,
#        2.545, 2.796, 2.891, 2.902, 3.015, 2.942, 2.747, 2.711, 2.921,
#        3.775, 3.867, 3.431, 3.249, 2.829, 2.534])

# %%
training_data[0:24].ravel()
# Out:
# array([22.172, 22.352, 21.452, 20.624, 20.624, 20.336, 25.34 , 22.712,
#        23.306, 24.98 , 25.916, 26.51 , 27.266, 27.59 , 28.778, 29.93 ,
#        31.91 , 32.9  , 33.998, 34.178, 34.52 , 35.042, 34.772, 34.448])

# %%
from mip import Model, xsum, BINARY

def action_by_mip(T_out, price):
    # price of main grid--------------------------------------------------------------------------------------------------------
    #price_Grid = [10, 10, 8.5, 9, 12, 9.2, 12.2, 24.5, 27, 27.5, 17.2, 16.5, 16.5, 16.2, 14, 9, 8.5, 8.7, 9.5, 8, 8.2, 8, 8.1, 8.1]
    number_time_slot = 24

    m = Model()

    # definition of variables of HVAC system -----------------------------------
    T_min = 66.2 # 19 C
    T_max = 75.2 # 24 C
    T = [m.add_var() for i in range(number_time_slot + 1)]
    y = [m.add_var(var_type=BINARY) for i in range(number_time_slot+1)]
    T[0] = T_out[0]
    x1 =[m.add_var() for i in range(number_time_slot + 1)]
    x1[0]=0
    x2 =[m.add_var() for i in range(number_time_slot + 1)]
    x2[0]=0
    x3 =[m.add_var() for i in range(number_time_slot + 1)]
    x3[0]=0
    w1 =[m.add_var(var_type=BINARY) for i in range(number_time_slot + 1)]
    w1[0]=0
    w2 =[m.add_var(var_type=BINARY) for i in range(number_time_slot + 1)]
    w2[0]=0
    w3 =[m.add_var(var_type=BINARY) for i in range(number_time_slot + 1)]
    w3[0]=0
    HVAC_energy = [m.add_var(lb=0, ub=20) for i in range(number_time_slot)]
    weight_coefficient = 100000

    # definition of objective function --------------------------------------------------------------------------------
    m.objective = xsum(HVAC_energy[i] * price[i] + weight_coefficient * (T_min * w1[i+1] - x1[i+1] + x3[i+1] - T_max * w3[i+1]) for i in range(number_time_slot))
    
    for i in range(number_time_slot):
        m += T[i+1] == 0.7 * T[i] + (1 - 0.7) * (T_out[i] + (2.5 / 0.14) * HVAC_energy[i])

    for i in range(number_time_slot+1):
        m += T_max <= T[i] - 0.001 + 1000 * (1-y[i])
        m += T_max >= T[i] - 1000 * y[i]

    for i in range(number_time_slot):
        m += HVAC_energy[i] <= 0 + 1000 * (1 - y[i])
        m += HVAC_energy[i] >= 0 - 1000 * (1 - y[i])
        
    for i in range(number_time_slot):
        m += 1 == w1[i+1] + w2[i+1] + w3[i+1]
        m += T[i+1] == x1[i+1] + x2[i+1] + x3[i+1]

    for i in range(number_time_slot):
        m += x1[i+1] <= T_min * w1[i+1]
        m += x1[i+1] >= -1000 * w1[i+1]

    for i in range(number_time_slot):
        m += x2[i+1] <= T_max * w2[i+1]
        m += x2[i+1] >= T_min * w2[i+1]

    for i in range(number_time_slot):
        m += x3[i+1] <= 1000 * w3[i+1]
        m += x3[i+1] >= T_max * w3[i+1]

    
    m.optimize()
    #print("the minimum value --------------------------------------------------------------------------")
    #print("optimal value =", m.objective_value)
    #print("temperature----------------------------------")
    T_in = []
    for i in range(number_time_slot):
        #print(i+1,"=",T[i+1].x)
        T_in.append(T[i+1].x)
    #print("HVAC energy ----------------------------------")
    HVAC = []
    for i in range(number_time_slot):
    #    print(i,"=", HVAC_energy[i].x)
        HVAC.append(HVAC_energy[i].x)
    
    return np.array(HVAC), np.array(T_in), m.objective_value
tempt1, tempt2, tempt3 = action_by_mip(training_data[0:24].ravel(), three_year_price[0:24].ravel())
tempt2
# Out:
# array([66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2,
#        66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2,
#        66.2, 66.2])

# %%
"""
best_HVAC_energy=[]
best_temperature = []
for i in range(0,training_data.shape[0],24):
    tempt1, tempt2, tempt3 = action_by_mip(training_data[i: i + 24].ravel(), three_year_price[i: i + 24].ravel())
    best_HVAC_energy.append(tempt1)
    best_temperature.append(tempt2)

best_energy = np.array(best_HVAC_energy)
np.savetxt("datasets/best_energy_2.csv", best_energy, delimiter=";")
best_temperature = np.array(best_temperature)
np.savetxt("datasets/best_temperature_2.csv", best_temperature, delimiter=";")
"""
best_energy = np.loadtxt("datasets/best_energy_2.csv",delimiter=";")
best_temperature = np.loadtxt("datasets/best_temperature_2.csv",delimiter=";")
best_energy.shape
# Out:
# (1095, 24)

# %%
plt.plot(best_energy,'b',label="actual")
plt.show()

# %%
plt.plot(best_temperature,'b',label="actual")
plt.show()

# %%
def create_data(T_out, T_in, price):
    data = []
    for d in range(0,T_out.shape[0],24):
        for h in range(24):
            data.append(T_out[d+h])
            if h == 0: 
                data.append(T_out[d+h])
            else:
                data.append(T_in[d+h-1])
            data.append(price[d+h])
            data.append(h)
    return np.array(data).reshape(-1,4)
X_train = create_data(training_data.ravel(), best_temperature.ravel(), three_year_price.ravel())
X_train.shape
# Out:
# (26280, 4)

# %%
x_train,x_valid = X_train[:24072],X_train[24072:]
tempt = best_energy.ravel()
y_train,y_valid = tempt[:24072], tempt[24072:]

# %%
import tensorflow as tf
from tensorflow import keras

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model = keras.models.Sequential([
    keras.layers.Dense(90, activation="relu", input_shape=[4], kernel_initializer="he_normal"),
    keras.layers.Dense(90, activation="relu", kernel_initializer="he_normal"),
    keras.layers.Dense(90, activation="relu", kernel_initializer="he_normal"),
    keras.layers.Dense(1)
])
model.compile(loss='mse',optimizer=opt)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 90)                450
# _________________________________________________________________
# dense_1 (Dense)              (None, 90)                8190
# _________________________________________________________________
# dense_2 (Dense)              (None, 90)                8190
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 91
# =================================================================
# Total params: 16,921
# Trainable params: 16,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model.fit(x_train, y_train, epochs=370, batch_size=24, verbose=2, shuffle=False, validation_data=(x_valid, y_valid))

# summarize history for loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.show()
# Out:
# Epoch 1/370
# 1003/1003 - 1s - loss: 45.8261 - val_loss: 0.5921
# Epoch 2/370
# 1003/1003 - 1s - loss: 0.6125 - val_loss: 0.5573
# Epoch 3/370
# 1003/1003 - 1s - loss: 0.4208 - val_loss: 0.3571
# Epoch 4/370
# 1003/1003 - 1s - loss: 0.3165 - val_loss: 0.3986
# Epoch 5/370
# 1003/1003 - 1s - loss: 0.3463 - val_loss: 0.3249
# Epoch 6/370
# 1003/1003 - 1s - loss: 0.3158 - val_loss: 0.3673
# Epoch 7/370
# 1003/1003 - 1s - loss: 0.3618 - val_loss: 0.2633
# Epoch 8/370
# 1003/1003 - 1s - loss: 0.3202 - val_loss: 0.2421
# Epoch 9/370
# 1003/1003 - 1s - loss: 0.3016 - val_loss: 0.2414
# Epoch 10/370
# 1003/1003 - 1s - loss: 0.2930 - val_loss: 0.2239
# Epoch 11/370
# 1003/1003 - 1s - loss: 0.2680 - val_loss: 0.2380
# Epoch 12/370
# 1003/1003 - 1s - loss: 0.2724 - val_loss: 0.2339
# Epoch 13/370
# 1003/1003 - 1s - loss: 0.2537 - val_loss: 0.2677
# Epoch 14/370
# 1003/1003 - 1s - loss: 0.2627 - val_loss: 0.2191
# Epoch 15/370
# 1003/1003 - 1s - loss: 0.2383 - val_loss: 0.2346
# Epoch 16/370
# 1003/1003 - 1s - loss: 0.2466 - val_loss: 0.2175
# Epoch 17/370
# 1003/1003 - 1s - loss: 0.2338 - val_loss: 0.2014
# Epoch 18/370
# 1003/1003 - 1s - loss: 0.2401 - val_loss: 0.2006
# Epoch 19/370
# 1003/1003 - 1s - loss: 0.2275 - val_loss: 0.2075
# Epoch 20/370
# 1003/1003 - 1s - loss: 0.2285 - val_loss: 0.1948
# Epoch 21/370
# 1003/1003 - 1s - loss: 0.2144 - val_loss: 0.1961
# Epoch 22/370
# 1003/1003 - 1s - loss: 0.2118 - val_loss: 0.1998
# Epoch 23/370
# 1003/1003 - 1s - loss: 0.2014 - val_loss: 0.1907
# Epoch 24/370
# 1003/1003 - 1s - loss: 0.2073 - val_loss: 0.1915
# Epoch 25/370
# 1003/1003 - 1s - loss: 0.2000 - val_loss: 0.1923
# Epoch 26/370
# 1003/1003 - 1s - loss: 0.1954 - val_loss: 0.1704
# Epoch 27/370
# 1003/1003 - 1s - loss: 0.1920 - val_loss: 0.1624
# Epoch 28/370
# 1003/1003 - 1s - loss: 0.1862 - val_loss: 0.1608
# Epoch 29/370
# 1003/1003 - 1s - loss: 0.1805 - val_loss: 0.1851
# Epoch 30/370
# 1003/1003 - 1s - loss: 0.1774 - val_loss: 0.1634
# Epoch 31/370
# 1003/1003 - 1s - loss: 0.1723 - val_loss: 0.1760
# Epoch 32/370
# 1003/1003 - 1s - loss: 0.1758 - val_loss: 0.1781
# Epoch 33/370
# 1003/1003 - 1s - loss: 0.1650 - val_loss: 0.1846
# Epoch 34/370
# 1003/1003 - 1s - loss: 0.1705 - val_loss: 0.1890
# Epoch 35/370
# 1003/1003 - 1s - loss: 0.0499 - val_loss: 0.1526
# Epoch 106/370
# 1003/1003 - 1s - loss: 0.0500 - val_loss: 0.1747
# Epoch 107/370
# 1003/1003 - 1s - loss: 0.0497 - val_loss: 0.1693
# Epoch 108/370
# 1003/1003 - 1s - loss: 0.0465 - val_loss: 0.1618
# Epoch 109/370
# 1003/1003 - 1s - loss: 0.0456 - val_loss: 0.1397
# Epoch 110/370
# 1003/1003 - 1s - loss: 0.0463 - val_loss: 0.1548
# Epoch 111/370
# 1003/1003 - 1s - loss: 0.0434 - val_loss: 0.1641
# Epoch 112/370
# 1003/1003 - 1s - loss: 0.0437 - val_loss: 0.1759
# Epoch 113/370
# 1003/1003 - 1s - loss: 0.0433 - val_loss: 0.1579
# Epoch 114/370
# 1003/1003 - 1s - loss: 0.0411 - val_loss: 0.1448
# Epoch 115/370
# 1003/1003 - 1s - loss: 0.0413 - val_loss: 0.1353
# Epoch 116/370
# 1003/1003 - 1s - loss: 0.0393 - val_loss: 0.1460
# Epoch 117/370
# 1003/1003 - 1s - loss: 0.0421 - val_loss: 0.1313
# Epoch 118/370
# 1003/1003 - 1s - loss: 0.0374 - val_loss: 0.1324
# Epoch 119/370
# 1003/1003 - 1s - loss: 0.0383 - val_loss: 0.1441
# Epoch 120/370
# 1003/1003 - 1s - loss: 0.0374 - val_loss: 0.1594
# Epoch 121/370
# 1003/1003 - 1s - loss: 0.0371 - val_loss: 0.1741
# Epoch 122/370
# 1003/1003 - 1s - loss: 0.0369 - val_loss: 0.1683
# Epoch 123/370
# 1003/1003 - 1s - loss: 0.0365 - val_loss: 0.1756
# Epoch 124/370
# 1003/1003 - 1s - loss: 0.0374 - val_loss: 0.1832
# Epoch 125/370
# 1003/1003 - 1s - loss: 0.0362 - val_loss: 0.1868
# Epoch 126/370
# 1003/1003 - 1s - loss: 0.0364 - val_loss: 0.1745
# Epoch 127/370
# 1003/1003 - 1s - loss: 0.0340 - val_loss: 0.1657
# Epoch 128/370
# 1003/1003 - 1s - loss: 0.0335 - val_loss: 0.1710
# Epoch 129/370
# 1003/1003 - 1s - loss: 0.0338 - val_loss: 0.1761
# Epoch 130/370
# 1003/1003 - 1s - loss: 0.0329 - val_loss: 0.1910
# Epoch 131/370
# 1003/1003 - 1s - loss: 0.0339 - val_loss: 0.1499
# Epoch 132/370
# 1003/1003 - 1s - loss: 0.0343 - val_loss: 0.1315
# Epoch 133/370
# 1003/1003 - 1s - loss: 0.0322 - val_loss: 0.1701
# Epoch 134/370
# 1003/1003 - 1s - loss: 0.0315 - val_loss: 0.1349
# Epoch 135/370
# 1003/1003 - 1s - loss: 0.0327 - val_loss: 0.1364
# Epoch 136/370
# 1003/1003 - 1s - loss: 0.0300 - val_loss: 0.1470
# Epoch 137/370
# 1003/1003 - 1s - loss: 0.0291 - val_loss: 0.1369
# Epoch 138/370
# 1003/1003 - 1s - loss: 0.0293 - val_loss: 0.1257
# Epoch 139/370
# 1003/1003 - 1s - loss: 0.0280 - val_loss: 0.1409
# Epoch 140/370
# 1003/1003 - 1s - loss: 0.0146 - val_loss: 0.0643
# Epoch 246/370
# 1003/1003 - 1s - loss: 0.0137 - val_loss: 0.0750
# Epoch 247/370
# 1003/1003 - 1s - loss: 0.0141 - val_loss: 0.0880
# Epoch 248/370
# 1003/1003 - 1s - loss: 0.0143 - val_loss: 0.0674
# Epoch 249/370
# 1003/1003 - 1s - loss: 0.0141 - val_loss: 0.0957
# Epoch 250/370
# 1003/1003 - 1s - loss: 0.0141 - val_loss: 0.1868
# Epoch 251/370
# 1003/1003 - 1s - loss: 0.0142 - val_loss: 0.1043
# Epoch 252/370
# 1003/1003 - 1s - loss: 0.0136 - val_loss: 0.0921
# Epoch 253/370
# 1003/1003 - 1s - loss: 0.0141 - val_loss: 0.0281
# Epoch 254/370
# 1003/1003 - 1s - loss: 0.0141 - val_loss: 0.0281
# Epoch 255/370
# 1003/1003 - 1s - loss: 0.0134 - val_loss: 0.1060
# Epoch 256/370
# 1003/1003 - 1s - loss: 0.0136 - val_loss: 0.0273
# Epoch 257/370
# 1003/1003 - 1s - loss: 0.0133 - val_loss: 0.0262
# Epoch 258/370
# 1003/1003 - 1s - loss: 0.0130 - val_loss: 0.0812
# Epoch 259/370
# 1003/1003 - 1s - loss: 0.0136 - val_loss: 0.1062
# Epoch 260/370
# 1003/1003 - 1s - loss: 0.0147 - val_loss: 0.0270
# Epoch 261/370
# 1003/1003 - 1s - loss: 0.0129 - val_loss: 0.0470
# Epoch 262/370
# 1003/1003 - 1s - loss: 0.0131 - val_loss: 0.0794
# Epoch 263/370
# 1003/1003 - 1s - loss: 0.0139 - val_loss: 0.0903
# Epoch 264/370
# 1003/1003 - 1s - loss: 0.0129 - val_loss: 0.0895
# Epoch 265/370
# 1003/1003 - 1s - loss: 0.0135 - val_loss: 0.0277
# Epoch 266/370
# 1003/1003 - 1s - loss: 0.0129 - val_loss: 0.0270
# Epoch 267/370
# 1003/1003 - 1s - loss: 0.0163 - val_loss: 0.0464
# Epoch 268/370
# 1003/1003 - 1s - loss: 0.0129 - val_loss: 0.0854
# Epoch 269/370
# 1003/1003 - 1s - loss: 0.0131 - val_loss: 0.0535
# Epoch 270/370
# 1003/1003 - 1s - loss: 0.0139 - val_loss: 0.0274
# Epoch 271/370
# 1003/1003 - 1s - loss: 0.0128 - val_loss: 0.0498
# Epoch 272/370
# 1003/1003 - 1s - loss: 0.0129 - val_loss: 0.0496
# Epoch 273/370
# 1003/1003 - 1s - loss: 0.0127 - val_loss: 0.0602
# Epoch 274/370
# 1003/1003 - 1s - loss: 0.0128 - val_loss: 0.0535
# Epoch 275/370
# 1003/1003 - 1s - loss: 0.0127 - val_loss: 0.0666
# Epoch 276/370
# 1003/1003 - 1s - loss: 0.0126 - val_loss: 0.0501
# Epoch 277/370
# 1003/1003 - 1s - loss: 0.0126 - val_loss: 0.0255
# Epoch 278/370
# 1003/1003 - 1s - loss: 0.0139 - val_loss: 0.0508
# Epoch 279/370
# 1003/1003 - 1s - loss: 0.0132 - val_loss: 0.0254
# Epoch 280/370
# 1003/1003 - 1s - loss: 0.0110 - val_loss: 0.0251
# Epoch 351/370
# 1003/1003 - 1s - loss: 0.0112 - val_loss: 0.0248
# Epoch 352/370
# 1003/1003 - 1s - loss: 0.0111 - val_loss: 0.1645
# Epoch 353/370
# 1003/1003 - 1s - loss: 0.0125 - val_loss: 0.1016
# Epoch 354/370
# 1003/1003 - 1s - loss: 0.0113 - val_loss: 0.0598
# Epoch 355/370
# 1003/1003 - 1s - loss: 0.0116 - val_loss: 0.1063
# Epoch 356/370
# 1003/1003 - 1s - loss: 0.0120 - val_loss: 0.0574
# Epoch 357/370
# 1003/1003 - 1s - loss: 0.0112 - val_loss: 0.0246
# Epoch 358/370
# 1003/1003 - 1s - loss: 0.0112 - val_loss: 0.0927
# Epoch 359/370
# 1003/1003 - 1s - loss: 0.0121 - val_loss: 0.0282
# Epoch 360/370
# 1003/1003 - 1s - loss: 0.0108 - val_loss: 0.0263
# Epoch 361/370
# 1003/1003 - 1s - loss: 0.0113 - val_loss: 0.1549
# Epoch 362/370
# 1003/1003 - 1s - loss: 0.0122 - val_loss: 0.0253
# Epoch 363/370
# 1003/1003 - 1s - loss: 0.0113 - val_loss: 0.0258
# Epoch 364/370
# 1003/1003 - 1s - loss: 0.0112 - val_loss: 0.0724
# Epoch 365/370
# 1003/1003 - 1s - loss: 0.0117 - val_loss: 0.1003
# Epoch 366/370
# 1003/1003 - 1s - loss: 0.0115 - val_loss: 0.1166
# Epoch 367/370
# 1003/1003 - 1s - loss: 0.0112 - val_loss: 0.0950
# Epoch 368/370
# 1003/1003 - 1s - loss: 0.0115 - val_loss: 0.0550
# Epoch 369/370
# 1003/1003 - 1s - loss: 0.0110 - val_loss: 0.1010
# Epoch 370/370
# 1003/1003 - 1s - loss: 0.0114 - val_loss: 0.0578

# %%
#model.save("MILP_IL_model_3")

# %%
test_data = new_df.loc['2016-01-01 00:00:00':'2016-03-31 23:00:00',:] 
test_data.info
# Out:
# <bound method DataFrame.info of                        Detroit
# datetime
# 2016-01-01 00:00:00  31.162232
# 2016-01-01 01:00:00  30.884000
# 2016-01-01 02:00:00  29.065036
# 2016-01-01 03:00:00  30.380000
# 2016-01-01 04:00:00  29.678000
# ...                        ...
# 2016-03-31 19:00:00  59.360000
# 2016-03-31 20:00:00  58.042302
# 2016-03-31 21:00:00  61.358000
# 2016-03-31 22:00:00  62.078045
# 2016-03-31 23:00:00  62.816000
#
# [2184 rows x 1 columns]>

# %%
testing_data= test_data.values
testing_data.shape
# Out:
# (2184, 1)

# %%
df19 = pd.read_csv('datasets/DAP/2020/jan_feb.csv')
df20 = pd.read_csv('datasets/DAP/2020/mar_apr.csv')
df21 = pd.read_csv('datasets/DAP/2020/may_jun.csv')

frames =[df19,df20,df21]
one_year_prices = pd.concat(frames)
one_year_prices.info
# Out:
# <bound method DataFrame.info of                  DateTime  day_ahead_pricing (michigan_hub) (miso)
# 0     2020-01-01 00:00:00                                    18.95
# 1     2020-01-01 01:00:00                                    18.34
# 2     2020-01-01 02:00:00                                    17.46
# 3     2020-01-01 03:00:00                                    17.36
# 4     2020-01-01 04:00:00                                    16.67
# ...                   ...                                      ...
# 1459  2020-06-30 19:00:00                                    41.58
# 1460  2020-06-30 20:00:00                                    32.08
# 1461  2020-06-30 21:00:00                                    29.04
# 1462  2020-06-30 22:00:00                                    26.27
# 1463  2020-06-30 23:00:00                                    23.49
#
# [4368 rows x 2 columns]>

# %%
one_year_prices.set_index("DateTime", inplace=True)
one_year_prices["day_ahead_pricing (michigan_hub) (miso)"] = one_year_prices["day_ahead_pricing (michigan_hub) (miso)"] / 10
tempt = one_year_prices["day_ahead_pricing (michigan_hub) (miso)"].values # one_year_price is dataframe, we have to convert to numpy array
one_year_price = np.array(tempt).reshape(-1,1)
one_year_price.shape
# Out:
# (4368, 1)

# %%
"""
best_HVAC_energy_testing=[]
best_tem_testing=[]
for i in range(0,testing_data.shape[0], 24):
    tempt1, tempt2, tempt3 = action_by_mip(testing_data[i: i + 24].ravel(), one_year_price[i: i + 24].ravel())
    best_HVAC_energy_testing.append(tempt1)
    best_tem_testing.append(tempt2)

best_energy_testing = np.array(best_HVAC_energy_testing)
best_temperature_testing = np.array(best_tem_testing)
np.savetxt("datasets/best_energy_testing_2.csv", best_energy_valid, delimiter=";")
np.savetxt("datasets/best_temperature_testing_2.csv", best_temperature_valid, delimiter=";")
"""

best_energy_testing = np.loadtxt("datasets/best_energy_testing_2.csv",delimiter=";")
best_temperature_testing = np.loadtxt("datasets/best_temperature_testing_2.csv",delimiter=";")
best_energy_testing.shape
# Out:
# (91, 24)

# %%
plt.plot(best_energy_testing,'b',label="actual")
plt.show()

# %%
def testing_model(test_data, test_prices):
    hvac_energy_day = []
    temperature_day = []
    T = test_data[0][0]
    for k in range(24): # max_step = 24
        input=[]
        input.append(test_data[k][0])
        input.append(T)
        input.append(test_prices[k][0])
        input.append(k)
        data = np.array(input).reshape(-1,4)
        hvac_energy = model.predict(data)
        hvac_energy_day.append(hvac_energy[0][0])
        T = 0.7 * T + (1-0.7)*(test_data[k][0]+(2.5 / 0.14) * hvac_energy[0][0])
        temperature_day.append(T)
    return np.array(hvac_energy_day), np.array(temperature_day)
hvac_energy_day, temperature_day = testing_model(testing_data[0:24],one_year_price[0:24])

# %%
plt.plot(best_energy_testing[0],'r',label="actual")
#plt.plot(best_energy_predict[3*24:3*24+24],'b',label="predict")
plt.plot(hvac_energy_day,'g',label="actual")
plt.show()

# %%
plt.plot(temperature_day,'r',label="actual")
plt.plot(best_temperature_testing[0],'b',label="predict")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

def mape_vectorized(a, b): 
    mask = a != 0
    return np.mean(np.fabs(a[mask] - b[mask])/a[mask])*100

mae1 = mean_absolute_error(best_energy_testing[0], hvac_energy_day.ravel())
mape1 = mape_vectorized(best_energy_testing[0], hvac_energy_day.ravel())
print("mae=",mae1, "mape=",mape1)
# Out:
# mae= 0.11386607276766335 mape= 4.452891142230999

# %%
total_hvac_energy = []
total_temperature = []
for i in range(91):
    test_data = testing_data[i*24:i*24+24]
    test_prices = one_year_price[i*24:i*24+24]
    hvac_energy_day, temperature_day = testing_model(test_data,test_prices)
    total_hvac_energy.append(hvac_energy_day)
    total_temperature.append(temperature_day)
    mae1 = mean_absolute_error(best_energy_testing[i], hvac_energy_day.ravel())
    mape1 = mape_vectorized(best_energy_testing[i], hvac_energy_day.ravel())
    print("i=",i,"mae=",mae1, "mape=",mape1)
# Out:
# i= 0 mae= 0.11386607276766335 mape= 4.452891142230999
# i= 1 mae= 0.10501675328319282 mape= 4.1037523887575045
# i= 2 mae= 0.07500764622774696 mape= 2.834591218394435
# i= 3 mae= 0.13026081936587797 mape= 4.8352437411186635
# i= 4 mae= 0.12703343239774106 mape= 4.060258398264467
# i= 5 mae= 0.11870291281739154 mape= 4.244562984225594
# i= 6 mae= 0.21807278337518773 mape= 10.351249003041818
# i= 7 mae= 0.1048803850979515 mape= 4.442235157127716
# i= 8 mae= 0.08757742009954661 mape= 4.317127117246317
# i= 9 mae= 0.10338066657409795 mape= 5.316688140714406
# i= 10 mae= 0.128391025270587 mape= 3.9182636608250823
# i= 11 mae= 0.1148161849723322 mape= 3.9127132168222425
# i= 12 mae= 0.131599487455917 mape= 4.096227511019557
# i= 13 mae= 0.0992504472860772 mape= 3.377679651833687
# i= 14 mae= 0.10447821925570493 mape= 4.140475134938307
# i= 15 mae= 0.0982956879803416 mape= 4.419050471816386
# i= 16 mae= 0.13291979980271026 mape= 4.83290288125417
# i= 17 mae= 0.11606601091763424 mape= 3.421412653990951
# i= 18 mae= 0.1341454262439604 mape= 4.095413998197095
# i= 19 mae= 0.13994751650693552 mape= 4.497625573846909
# i= 20 mae= 0.12360900435676718 mape= 4.1147037291770125
# i= 21 mae= 0.12604064716196095 mape= 4.583788536935563
# i= 22 mae= 0.12175829979812623 mape= 4.33077225655828
# i= 23 mae= 0.11993506102913842 mape= 4.239438708573841
# i= 24 mae= 0.10532648878241015 mape= 4.297381542379534
# i= 25 mae= 0.10411463164541283 mape= 5.293159375360093
# i= 26 mae= 0.10121345679295539 mape= 4.113075955209763
# i= 27 mae= 0.10298223845553149 mape= 4.11235113662628
# i= 28 mae= 0.11989341817873522 mape= 4.757098136991948
# i= 29 mae= 0.09979533209025672 mape= 4.04181382582323
# i= 30 mae= 0.09033081424034163 mape= 4.5739858898110946
# i= 31 mae= 0.15062795516075184 mape= 10.40934571021978
# i= 32 mae= 0.1388811013639432 mape= 5.844138568732185
# i= 33 mae= 0.08552681088987213 mape= 4.827293433919469
# i= 34 mae= 0.08404074818042336 mape= 3.5758800788882725
# i= 35 mae= 0.11660061219968469 mape= 4.445618399511153
# i= 36 mae= 0.11360866128699187 mape= 4.714398102461378
# i= 37 mae= 0.08810526955414022 mape= 3.742719469557994
# i= 38 mae= 0.11266811091089475 mape= 6.188908884710698
# i= 39 mae= 0.09000419912560968 mape= 3.589177064013039
# i= 40 mae= 0.13964538980960492 mape= 4.947276356828755
# i= 41 mae= 0.13781542648178136 mape= 4.2293401296951725
# i= 42 mae= 0.24369988376148152 mape= 9.460002148730895
# i= 43 mae= 0.13415046076234718 mape= 3.80610764062801
        energy_cost_model += total_hvac_energy[i][j] * one_year_price[i*24 + j]
        energy_cost_milp += best_energy_testing[i][j] * one_year_price[i*24 + j]
    mae1 = np.fabs(energy_cost_milp - energy_cost_model)
    mape1 = np.fabs(energy_cost_milp - energy_cost_model) / energy_cost_milp * 100
    print("i=",i,"milp =",energy_cost_milp,"model=", energy_cost_model, "mae=",mae1, "mape=",mape1)
# Out:
# i= 0 milp = [128.21770793] model= [122.38689463] mae= [5.83081331] mape= [4.54758816]
# i= 1 milp = [121.7736094] model= [116.34051392] mae= [5.43309549] mape= [4.46163624]
# i= 2 milp = [111.79494807] model= [108.01335165] mae= [3.78159642] mape= [3.38261834]
# i= 3 milp = [128.63497068] model= [122.03679568] mae= [6.598175] mape= [5.12937887]
# i= 4 milp = [164.72386835] model= [157.78178321] mae= [6.94208514] mape= [4.21437719]
# i= 5 milp = [143.76466221] model= [137.12113623] mae= [6.64352597] mape= [4.62111194]
# i= 6 milp = [123.88192839] model= [118.02306775] mae= [5.85886064] mape= [4.7293909]
# i= 7 milp = [108.66476472] model= [103.14347852] mae= [5.5212862] mape= [5.08102715]
# i= 8 milp = [83.78098534] model= [79.44826448] mae= [4.33272086] mape= [5.17148473]
# i= 9 milp = [89.48939393] model= [84.74320696] mae= [4.74618697] mape= [5.3036307]
# i= 10 milp = [154.5102354] model= [148.1626796] mae= [6.34755579] mape= [4.10817819]
# i= 11 milp = [175.86134258] model= [168.86626342] mae= [6.99507915] mape= [3.97761046]
# i= 12 milp = [177.63862339] model= [170.21045448] mae= [7.42816891] mape= [4.18161814]
# i= 13 milp = [158.18699253] model= [152.52693487] mae= [5.66005766] mape= [3.57808033]
# i= 14 milp = [123.96415341] model= [118.31801455] mae= [5.64613886] mape= [4.55465448]
# i= 15 milp = [123.28020931] model= [117.56099318] mae= [5.71921613] mape= [4.63920054]
# i= 16 milp = [134.99280297] model= [128.31734853] mae= [6.67545443] mape= [4.94504469]
# i= 17 milp = [182.60167433] model= [176.23670896] mae= [6.36496537] mape= [3.4857103]
# i= 18 milp = [210.33885798] model= [201.66667593] mae= [8.67218205] mape= [4.12295766]
# i= 19 milp = [183.09340933] model= [174.67021453] mae= [8.42319481] mape= [4.60049045]
# i= 20 milp = [154.74081013] model= [148.148843] mae= [6.59196713] mape= [4.26000557]
# i= 21 milp = [138.43688455] model= [131.76607106] mae= [6.6708135] mape= [4.81866774]
# i= 22 milp = [128.78835504] model= [122.76981763] mae= [6.01853741] mape= [4.6732]
# i= 23 milp = [131.2652753] model= [125.24499595] mae= [6.02027935] mape= [4.58634573]
# i= 24 milp = [106.61725534] model= [101.36774012] mae= [5.24951521] mape= [4.92370132]
# i= 25 milp = [96.30739898] model= [90.88528874] mae= [5.42211024] mape= [5.63000382]
# i= 26 milp = [129.33551111] model= [123.68739879] mae= [5.64811232] mape= [4.36702362]
# i= 27 milp = [125.4511308] model= [119.6752695] mae= [5.7758613] mape= [4.60407273]
# i= 28 milp = [137.10612859] model= [130.18140418] mae= [6.92472441] mape= [5.05063084]
# i= 29 milp = [108.99523153] model= [103.80345938] mae= [5.19177215] mape= [4.7633021]
# i= 30 milp = [71.95767817] model= [69.00695925] mae= [2.95071892] mape= [4.10063108]
# i= 31 milp = [59.19776369] model= [53.14959643] mae= [6.04816726] mape= [10.2168847]
# i= 32 milp = [101.76423133] model= [95.34890651] mae= [6.41532482] mape= [6.30410581]
# i= 33 milp = [61.49875373] model= [59.68481063] mae= [1.8139431] mape= [2.94956075]
# i= 34 milp = [107.46458884] model= [103.33715766] mae= [4.12743118] mape= [3.84073603]
# i= 35 milp = [127.52832376] model= [121.37940008] mae= [6.14892368] mape= [4.82161413]
# i= 36 milp = [117.95956133] model= [111.88250254] mae= [6.07705879] mape= [5.15181535]
# i= 37 milp = [98.64583042] model= [94.33213206] mae= [4.31369835] mape= [4.37291504]
# i= 38 milp = [73.5280812] model= [68.46366178] mae= [5.06441942] mape= [6.88773506]
# i= 39 milp = [111.94670256] model= [107.71725285] mae= [4.22944971] mape= [3.77809227]
# i= 40 milp = [135.58815417] model= [128.69285216] mae= [6.89530201] mape= [5.08547524]
# i= 41 milp = [173.20201641] model= [165.78580333] mae= [7.41621308] mape= [4.28182837]
# i= 42 milp = [179.67923795] model= [172.43131488] mae= [7.24792306] mape= [4.03381222]
# i= 43 milp = [217.61470364] model= [209.0999799] mae= [8.51472374] mape= [3.91275203]
# i= 44 milp = [182.20446155] model= [176.11165766] mae= [6.09280389] mape= [3.34393782]
# i= 45 milp = [130.88995385] model= [125.62178673] mae= [5.26816711] mape= [4.0248827]
# i= 46 milp = [115.61701285] model= [110.10158719] mae= [5.51542566] mape= [4.7704274]
# i= 47 milp = [107.39034138] model= [102.26333155] mae= [5.12700983] mape= [4.77418152]
# i= 48 milp = [157.40036195] model= [150.11178389] mae= [7.28857807] mape= [4.63059803]
# i= 49 milp = [99.72962056] model= [95.86974213] mae= [3.85987843] mape= [3.87034304]
# i= 50 milp = [46.94297715] model= [37.94209438] mae= [9.00088278] mape= [19.1740774]
# i= 51 milp = [75.37669506] model= [69.05509261] mae= [6.32160245] mape= [8.38668033]
# i= 52 milp = [91.1261098] model= [85.30788849] mae= [5.81822131] mape= [6.38480159]
# i= 53 milp = [108.51943196] model= [102.54290343] mae= [5.97652853] mape= [5.50733488]
# i= 54 milp = [97.52746157] model= [92.61336859] mae= [4.91409299] mape= [5.03867619]
# i= 55 milp = [110.15311684] model= [105.68065929] mae= [4.47245756] mape= [4.0602188]
# i= 56 milp = [129.5858362] model= [123.37388889] mae= [6.21194732] mape= [4.79369312]
# i= 57 milp = [123.2479719] model= [117.79922317] mae= [5.44874873] mape= [4.42096421]
# i= 58 milp = [67.17296305] model= [63.09360396] mae= [4.0793591] mape= [6.0729182]
# i= 59 milp = [58.54123249] model= [53.15529682] mae= [5.38593567] mape= [9.20024305]
# i= 60 milp = [116.04285614] model= [108.99809014] mae= [7.044766] mape= [6.07083128]
# i= 61 milp = [135.49718743] model= [128.86006555] mae= [6.63712188] mape= [4.8983466]
# i= 62 milp = [124.45546407] model= [118.52879342] mae= [5.92667065] mape= [4.76208152]
# i= 63 milp = [113.73501842] model= [107.98059221] mae= [5.7544262] mape= [5.05950259]
# i= 64 milp = [116.34432572] model= [110.50342823] mae= [5.84089749] mape= [5.02035441]
# i= 65 milp = [106.97874644] model= [101.43715385] mae= [5.54159259] mape= [5.18008743]
# i= 66 milp = [61.73613938] model= [60.56577152] mae= [1.17036786] mape= [1.8957581]
# i= 67 milp = [29.80904348] model= [23.21294069] mae= [6.59610279] mape= [22.12785792]
# i= 68 milp = [17.77800737] model= [19.34737379] mae= [1.56936641] mape= [8.82757207]
# i= 69 milp = [31.53295341] model= [29.76222067] mae= [1.77073274] mape= [5.61549918]
# i= 70 milp = [71.12537349] model= [64.50336008] mae= [6.62201341] mape= [9.31033903]
# i= 71 milp = [70.05559166] model= [64.40064149] mae= [5.65495017] mape= [8.07208966]
# i= 72 milp = [61.52957189] model= [52.37578561] mae= [9.15378629] mape= [14.87705181]
# i= 73 milp = [53.23554572] model= [47.12410532] mae= [6.1114404] mape= [11.47999954]
# i= 74 milp = [55.19110303] model= [45.77486935] mae= [9.41623368] mape= [17.06114422]
# i= 75 milp = [54.16758626] model= [45.19139107] mae= [8.97619519] mape= [16.57115594]
# i= 76 milp = [52.30143497] model= [43.81806489] mae= [8.48337008] mape= [16.22014785]
# i= 77 milp = [74.10572827] model= [69.02168996] mae= [5.08403832] mape= [6.86052001]
# i= 78 milp = [84.79400231] model= [78.9515167] mae= [5.84248561] mape= [6.89021092]
# i= 79 milp = [98.0542945] model= [92.4585578] mae= [5.5957367] mape= [5.70677371]
# i= 80 milp = [86.51894778] model= [81.2216235] mae= [5.29732428] mape= [6.12273313]
# i= 81 milp = [83.01298991] model= [78.39441978] mae= [4.61857013] mape= [5.56367158]
# i= 82 milp = [57.51372796] model= [52.21699218] mae= [5.29673578] mape= [9.20951565]
# i= 83 milp = [70.8241434] model= [68.766918] mae= [2.0572254] mape= [2.90469507]
# i= 84 milp = [81.20926073] model= [74.23905904] mae= [6.97020169] mape= [8.58301336]
# i= 85 milp = [83.81402948] model= [78.43082315] mae= [5.38320633] mape= [6.42279862]
# i= 86 milp = [50.04101958] model= [45.45705842] mae= [4.58396116] mape= [9.16040721]
# i= 87 milp = [36.63459469] model= [36.93312631] mae= [0.29853162] mape= [0.81488992]
# i= 88 milp = [67.44241031] model= [62.026178] mae= [5.4162323] mape= [8.03089966]
# i= 89 milp = [62.03020416] model= [57.4546548] mae= [4.57554935] mape= [7.37632483]
# i= 90 milp = [26.05408433] model= [17.81568069] mae= [8.23840364] mape= [31.62039217]

# %%
plt.plot(total_temperature,'r',label="actual")
#plt.plot(best_temperature_valid[43],'b',label="predict")
plt.show()

# %%
plt.plot(best_energy_testing[67],'r',label="actual")
plt.plot(total_hvac_energy[67],'g',label="actual")
plt.show()

# %%
#hvac_energy_model = np.array(total_hvac_energy)
#temperature_model = np.array(total_temperature)
#np.savetxt("datasets/hvac_energy_model_2.csv", hvac_energy_model, delimiter=";")
#np.savetxt("datasets/temperature_model_2.csv", temperature_model, delimiter=";")
