# %%
import pandas as pd
df1 = pd.read_csv('datasets/DAP/2017/jan_feb.csv')
df2 = pd.read_csv('datasets/DAP/2017/mar_apr.csv')
df3 = pd.read_csv('datasets/DAP/2017/may_jun.csv')
df4 = pd.read_csv('datasets/DAP/2017/july_august.csv')
df5 = pd.read_csv('datasets/DAP/2017/sep_oct.csv')
df6 = pd.read_csv('datasets/DAP/2017/nov_dec.csv')

df7 = pd.read_csv('datasets/DAP/2018/jan_feb.csv')
df8 = pd.read_csv('datasets/DAP/2018/mar_apr.csv')
df9 = pd.read_csv('datasets/DAP/2018/may_jun.csv')
df10 = pd.read_csv('datasets/DAP/2018/july_august.csv')
df11 = pd.read_csv('datasets/DAP/2018/sep_oct.csv')
df12 = pd.read_csv('datasets/DAP/2018/nov_dec.csv')

df13 = pd.read_csv('datasets/DAP/2019/jan_feb.csv')
df14 = pd.read_csv('datasets/DAP/2019/mar_apr.csv')
df15 = pd.read_csv('datasets/DAP/2019/may_jun.csv')
df16 = pd.read_csv('datasets/DAP/2019/july_august.csv')
df17 = pd.read_csv('datasets/DAP/2019/sep_oct.csv')
df18 = pd.read_csv('datasets/DAP/2019/nov_dec.csv')


frames =[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18]
three_year_prices = pd.concat(frames)

# %%
three_year_prices.info
# Out:
# <bound method DataFrame.info of                  DateTime  day_ahead_pricing (michigan_hub) (miso)
# 0     2017-01-01 00:00:00                                    24.36
# 1     2017-01-01 01:00:00                                    23.27
# 2     2017-01-01 02:00:00                                    22.57
# 3     2017-01-01 03:00:00                                    22.89
# 4     2017-01-01 04:00:00                                    22.38
# ...                   ...                                      ...
# 1459  2019-12-31 19:00:00                                    27.63
# 1460  2019-12-31 20:00:00                                    26.66
# 1461  2019-12-31 21:00:00                                    24.50
# 1462  2019-12-31 22:00:00                                    21.76
# 1463  2019-12-31 23:00:00                                    20.75
#
# [26280 rows x 2 columns]>

# %%
import numpy as np

three_year_prices.set_index("DateTime", inplace=True)
three_year_prices["day_ahead_pricing (michigan_hub) (miso)"] = three_year_prices["day_ahead_pricing (michigan_hub) (miso)"] / 10 # convert to cent/kwh
tempt = three_year_prices["day_ahead_pricing (michigan_hub) (miso)"].values
three_year_price = np.array(tempt).reshape(-1,1)
three_year_price.shape
# Out:
# (26280, 1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
three_year_prices["day_ahead_pricing (michigan_hub) (miso)"].plot(figsize=(20,5))
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\tf_gpu\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
df = pd.read_csv('datasets/weather/temperature.csv')

# %%
df.set_index('datetime',inplace=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df["Detroit"].plot(figsize=(20,5))
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\tf_gpu\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
selected_columns = df[["Detroit"]]
new_df=selected_columns.copy()
new_df.head()
# Out:
#                         Detroit
# datetime
# 2012-10-01 12:00:00         NaN
# 2012-10-01 13:00:00  284.030000
# 2012-10-01 14:00:00  284.069789
# 2012-10-01 15:00:00  284.173965
# 2012-10-01 16:00:00  284.278140

# %%
#T(°F) = T(K) × 9/5 - 459.67
new_df['Detroit'] = new_df['Detroit'] * 9 / 5 - 459.67
new_df.head()
# Out:
#                        Detroit
# datetime
# 2012-10-01 12:00:00        NaN
# 2012-10-01 13:00:00  51.584000
# 2012-10-01 14:00:00  51.655621
# 2012-10-01 15:00:00  51.843136
# 2012-10-01 16:00:00  52.030652

# %%
input_data = new_df.loc['2013-01-01 00:00:00':'2015-12-31 23:00:00',:]

# %%
training_data = input_data.values
training_data.shape
# Out:
# (26280, 1)

# %%
three_year_price[0:24].ravel()
# Out:
# array([2.436, 2.327, 2.257, 2.289, 2.238, 2.298, 2.291, 2.405, 2.499,
#        2.545, 2.796, 2.891, 2.902, 3.015, 2.942, 2.747, 2.711, 2.921,
#        3.775, 3.867, 3.431, 3.249, 2.829, 2.534])

# %%
training_data[0:24].ravel()
# Out:
# array([22.172, 22.352, 21.452, 20.624, 20.624, 20.336, 25.34 , 22.712,
#        23.306, 24.98 , 25.916, 26.51 , 27.266, 27.59 , 28.778, 29.93 ,
#        31.91 , 32.9  , 33.998, 34.178, 34.52 , 35.042, 34.772, 34.448])

# %%
from mip import Model, xsum, BINARY

def action_by_mip(T_out, price):
    # price of main grid--------------------------------------------------------------------------------------------------------
    #price_Grid = [10, 10, 8.5, 9, 12, 9.2, 12.2, 24.5, 27, 27.5, 17.2, 16.5, 16.5, 16.2, 14, 9, 8.5, 8.7, 9.5, 8, 8.2, 8, 8.1, 8.1]
    number_time_slot = 24

    m = Model()

    # definition of variables of HVAC system -----------------------------------
    T_min = 66.2 # 19 C
    T_max = 75.2 # 24 C
    T = [m.add_var() for i in range(number_time_slot + 1)]
    y = [m.add_var(var_type=BINARY) for i in range(number_time_slot+1)]
    T[0] = T_out[0]
    x1 =[m.add_var() for i in range(number_time_slot + 1)]
    x1[0]=0
    x2 =[m.add_var() for i in range(number_time_slot + 1)]
    x2[0]=0
    x3 =[m.add_var() for i in range(number_time_slot + 1)]
    x3[0]=0
    w1 =[m.add_var(var_type=BINARY) for i in range(number_time_slot + 1)]
    w1[0]=0
    w2 =[m.add_var(var_type=BINARY) for i in range(number_time_slot + 1)]
    w2[0]=0
    w3 =[m.add_var(var_type=BINARY) for i in range(number_time_slot + 1)]
    w3[0]=0
    HVAC_energy = [m.add_var(lb=0, ub=20) for i in range(number_time_slot)]
    weight_coefficient = 100000

    # definition of objective function --------------------------------------------------------------------------------
    m.objective = xsum(HVAC_energy[i] * price[i] + weight_coefficient * (T_min * w1[i+1] - x1[i+1] + x3[i+1] - T_max * w3[i+1]) for i in range(number_time_slot))
    
    for i in range(number_time_slot):
        m += T[i+1] == 0.7 * T[i] + (1 - 0.7) * (T_out[i] + (2.5 / 0.14) * HVAC_energy[i])

    for i in range(number_time_slot+1):
        m += T_max <= T[i] - 0.001 + 1000 * (1-y[i])
        m += T_max >= T[i] - 1000 * y[i]

    for i in range(number_time_slot):
        m += HVAC_energy[i] <= 0 + 1000 * (1 - y[i])
        m += HVAC_energy[i] >= 0 - 1000 * (1 - y[i])
        
    for i in range(number_time_slot):
        m += 1 == w1[i+1] + w2[i+1] + w3[i+1]
        m += T[i+1] == x1[i+1] + x2[i+1] + x3[i+1]

    for i in range(number_time_slot):
        m += x1[i+1] <= T_min * w1[i+1]
        m += x1[i+1] >= -1000 * w1[i+1]

    for i in range(number_time_slot):
        m += x2[i+1] <= T_max * w2[i+1]
        m += x2[i+1] >= T_min * w2[i+1]

    for i in range(number_time_slot):
        m += x3[i+1] <= 1000 * w3[i+1]
        m += x3[i+1] >= T_max * w3[i+1]

    
    m.optimize()
    #print("the minimum value --------------------------------------------------------------------------")
    #print("optimal value =", m.objective_value)
    #print("temperature----------------------------------")
    T_in = []
    for i in range(number_time_slot):
        #print(i+1,"=",T[i+1].x)
        T_in.append(T[i+1].x)
    #print("HVAC energy ----------------------------------")
    HVAC = []
    for i in range(number_time_slot):
    #    print(i,"=", HVAC_energy[i].x)
        HVAC.append(HVAC_energy[i].x)
    
    return np.array(HVAC), np.array(T_in), m.objective_value
tempt1, tempt2, tempt3 = action_by_mip(training_data[0:24].ravel(), three_year_price[0:24].ravel())
tempt2
# Out:
# array([66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2,
#        66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2, 66.2,
#        66.2, 66.2])

# %%
"""
best_HVAC_energy=[]
best_temperature = []
for i in range(0,training_data.shape[0],24):
    tempt1, tempt2, tempt3 = action_by_mip(training_data[i: i + 24].ravel(), three_year_price[i: i + 24].ravel())
    best_HVAC_energy.append(tempt1)
    best_temperature.append(tempt2)

best_energy = np.array(best_HVAC_energy)
np.savetxt("datasets/best_energy_2.csv", best_energy, delimiter=";")
best_temperature = np.array(best_temperature)
np.savetxt("datasets/best_temperature_2.csv", best_temperature, delimiter=";")
"""
best_energy = np.loadtxt("datasets/best_energy_2.csv",delimiter=";")
best_temperature = np.loadtxt("datasets/best_temperature_2.csv",delimiter=";")
best_energy.shape
# Out:
# (1095, 24)

# %%
plt.plot(best_energy,'b',label="actual")
plt.show()

# %%
plt.plot(best_temperature,'b',label="actual")
plt.show()

# %%
def create_data(T_out, T_in, price):
    data = []
    for d in range(0,T_out.shape[0],24):
        for h in range(24):
            data.append(T_out[d+h])
            if h == 0: 
                data.append(T_out[d+h])
            else:
                data.append(T_in[d+h-1])
            data.append(price[d+h])
            data.append(h)
    return np.array(data).reshape(-1,4)
X_train = create_data(training_data.ravel(), best_temperature.ravel(), three_year_price.ravel())
X_train.shape
# Out:
# (26280, 4)

# %%
x_train,x_valid = X_train[:24072],X_train[24072:]
tempt = best_energy.ravel()
y_train,y_valid = tempt[:24072], tempt[24072:]

# %%
import tensorflow as tf
from tensorflow import keras

opt = tf.keras.optimizers.Adam(learning_rate=0.0001)

model = keras.models.Sequential([
    keras.layers.Dense(90, activation="relu", input_shape=[4], kernel_initializer="he_normal"),
    keras.layers.Dense(90, activation="relu", kernel_initializer="he_normal"),
    keras.layers.Dense(90, activation="relu", kernel_initializer="he_normal"),
    keras.layers.Dense(1)
])
model.compile(loss='mse',optimizer=opt)
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 90)                450
# _________________________________________________________________
# dense_41 (Dense)             (None, 90)                8190
# _________________________________________________________________
# dense_42 (Dense)             (None, 90)                8190
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                
# Epoch 351/370
# 24072/24072 - 1s - loss: 0.0104 - val_loss: 0.0262
# Epoch 352/370
# 24072/24072 - 1s - loss: 0.0103 - val_loss: 0.0261
# Epoch 353/370
# 24072/24072 - 1s - loss: 0.0105 - val_loss: 0.0273
# Epoch 354/370
# 24072/24072 - 1s - loss: 0.0102 - val_loss: 0.0261
# Epoch 355/370
# 24072/24072 - 1s - loss: 0.0101 - val_loss: 0.0266
# Epoch 356/370
# 24072/24072 - 1s - loss: 0.0110 - val_loss: 0.0266
# Epoch 357/370
# 24072/24072 - 1s - loss: 0.0102 - val_loss: 0.0258
# Epoch 358/370
# 24072/24072 - 1s - loss: 0.0105 - val_loss: 0.0843
# Epoch 359/370
# 24072/24072 - 1s - loss: 0.0110 - val_loss: 0.0790
# Epoch 360/370
# 24072/24072 - 1s - loss: 0.0102 - val_loss: 0.1183
# Epoch 361/370
# 24072/24072 - 1s - loss: 0.0108 - val_loss: 0.0769
# Epoch 362/370
# 24072/24072 - 1s - loss: 0.0100 - val_loss: 0.1108
# Epoch 363/370
# 24072/24072 - 1s - loss: 0.0106 - val_loss: 0.0961
# Epoch 364/370
# 24072/24072 - 1s - loss: 0.0101 - val_loss: 0.0270
# Epoch 365/370
# 24072/24072 - 1s - loss: 0.0103 - val_loss: 0.0265
# Epoch 366/370
# 24072/24072 - 1s - loss: 0.0108 - val_loss: 0.0259
# Epoch 367/370
# 24072/24072 - 1s - loss: 0.0096 - val_loss: 0.0257
# Epoch 368/370
# 24072/24072 - 1s - loss: 0.0109 - val_loss: 0.0965
# Epoch 369/370
# 24072/24072 - 1s - loss: 0.0103 - val_loss: 0.0909
# Epoch 370/370
# 24072/24072 - 1s - loss: 0.0103 - val_loss: 0.0270

# %%
#model.save("MILP_IL_model_3")
# Out:
# INFO:tensorflow:Assets written to: MILP_IL_model_3\assets

# %%
test_data = new_df.loc['2016-01-01 00:00:00':'2016-03-31 23:00:00',:] 
test_data.info
# Out:
# <bound method DataFrame.info of                        Detroit
# datetime
# 2016-01-01 00:00:00  31.162232
# 2016-01-01 01:00:00  30.884000
# 2016-01-01 02:00:00  29.065036
# 2016-01-01 03:00:00  30.380000
# 2016-01-01 04:00:00  29.678000
# ...                        ...
# 2016-03-31 19:00:00  59.360000
# 2016-03-31 20:00:00  58.042302
# 2016-03-31 21:00:00  61.358000
# 2016-03-31 22:00:00  62.078045
# 2016-03-31 23:00:00  62.816000
#
# [2184 rows x 1 columns]>

# %%
testing_data= test_data.values
testing_data.shape
# Out:
# (2184, 1)

# %%
df19 = pd.read_csv('datasets/DAP/2020/jan_feb.csv')
df20 = pd.read_csv('datasets/DAP/2020/mar_apr.csv')
df21 = pd.read_csv('datasets/DAP/2020/may_jun.csv')

frames =[df19,df20,df21]
one_year_prices = pd.concat(frames)
one_year_prices.info
# Out:
# <bound method DataFrame.info of                  DateTime  day_ahead_pricing (michigan_hub) (miso)
# 0     2020-01-01 00:00:00                                    18.95
# 1     2020-01-01 01:00:00                                    18.34
# 2     2020-01-01 02:00:00                                    17.46
# 3     2020-01-01 03:00:00                                    17.36
# 4     2020-01-01 04:00:00                                    16.67
# ...                   ...                                      ...
# 1459  2020-06-30 19:00:00                                    41.58
# 1460  2020-06-30 20:00:00                                    32.08
# 1461  2020-06-30 21:00:00                                    29.04
# 1462  2020-06-30 22:00:00                                    26.27
# 1463  2020-06-30 23:00:00                                    23.49
#
# [4368 rows x 2 columns]>

# %%
one_year_prices.set_index("DateTime", inplace=True)
one_year_prices["day_ahead_pricing (michigan_hub) (miso)"] = one_year_prices["day_ahead_pricing (michigan_hub) (miso)"] / 10
tempt = one_year_prices["day_ahead_pricing (michigan_hub) (miso)"].values # one_year_price is dataframe, we have to convert to numpy array
one_year_price = np.array(tempt).reshape(-1,1)
one_year_price.shape
# Out:
# (4368, 1)

# %%
"""
best_HVAC_energy_testing=[]
best_tem_testing=[]
for i in range(0,testing_data.shape[0], 24):
    tempt1, tempt2, tempt3 = action_by_mip(testing_data[i: i + 24].ravel(), one_year_price[i: i + 24].ravel())
    best_HVAC_energy_testing.append(tempt1)
    best_tem_testing.append(tempt2)

best_energy_testing = np.array(best_HVAC_energy_testing)
best_temperature_testing = np.array(best_tem_testing)
np.savetxt("datasets/best_energy_testing_2.csv", best_energy_valid, delimiter=";")
np.savetxt("datasets/best_temperature_testing_2.csv", best_temperature_valid, delimiter=";")
"""

best_energy_testing = np.loadtxt("datasets/best_energy_testing_2.csv",delimiter=";")
best_temperature_testing = np.loadtxt("datasets/best_temperature_testing_2.csv",delimiter=";")
best_energy_testing.shape
# Out:
# (91, 24)

# %%
plt.plot(best_energy_testing,'b',label="actual")
plt.show()

# %%
def testing_model(test_data, test_prices):
    hvac_energy_day = []
    temperature_day = []
    T = test_data[0][0]
    for k in range(24): # max_step = 24
        input=[]
        input.append(test_data[k][0])
        input.append(T)
        input.append(test_prices[k][0])
        input.append(k)
        data = np.array(input).reshape(-1,4)
        hvac_energy = model.predict(data)
        hvac_energy_day.append(hvac_energy[0][0])
        T = 0.7 * T + (1-0.7)*(test_data[k][0]+(2.5 / 0.14) * hvac_energy[0][0])
        temperature_day.append(T)
    return np.array(hvac_energy_day), np.array(temperature_day)
hvac_energy_day, temperature_day = testing_model(testing_data[0:24],one_year_price[0:24])

# %%
plt.plot(best_energy_testing[0],'r',label="actual")
#plt.plot(best_energy_predict[3*24:3*24+24],'b',label="predict")
plt.plot(hvac_energy_day,'g',label="actual")
plt.show()

# %%
plt.plot(temperature_day,'r',label="actual")
plt.plot(best_temperature_testing[0],'b',label="predict")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

def mape_vectorized(a, b): 
    mask = a != 0
    return np.mean(np.fabs(a[mask] - b[mask])/a[mask])*100

mae1 = mean_absolute_error(best_energy_testing[0], hvac_energy_day.ravel())
mape1 = mape_vectorized(best_energy_testing[0], hvac_energy_day.ravel())
print("mae=",mae1, "mape=",mape1)
# Out:
# mae= 0.031487926363592045 mape= 1.2669462627063042

# %%
total_hvac_energy = []
total_temperature = []
for i in range(91):
    test_data = testing_data[i*24:i*24+24]
    test_prices = one_year_price[i*24:i*24+24]
    hvac_energy_day, temperature_day = testing_model(test_data,test_prices)
    total_hvac_energy.append(hvac_energy_day)
    total_temperature.append(temperature_day)
    mae1 = mean_absolute_error(best_energy_testing[i], hvac_energy_day.ravel())
    mape1 = mape_vectorized(best_energy_testing[i], hvac_energy_day.ravel())
    print("i=",i,"mae=",mae1, "mape=",mape1)
# Out:
# i= 0 mae= 0.031487926363592045 mape= 1.2669462627063042
# i= 1 mae= 0.03631396791189561 mape= 1.7296776725556007
# i= 2 mae= 0.03633006538805675 mape= 1.6300948602374938
# i= 3 mae= 0.03799577618296146 mape= 1.4616096031536745
# i= 4 mae= 0.027647488765344452 mape= 1.0035797513358802
# i= 5 mae= 0.04098248262427026 mape= 1.6589624715204352
# i= 6 mae= 0.14285457511495067 mape= 7.701882655539409
# i= 7 mae= 0.03271418669317045 mape= 1.4573922171369402
# i= 8 mae= 0.033485888803091966 mape= 2.160029005909221
# i= 9 mae= 0.053576109916113474 mape= 3.0882698118084995
# i= 10 mae= 0.07925427843236683 mape= 2.6514008393011474
# i= 11 mae= 0.02920547474152659 mape= 1.0741781064185316
# i= 12 mae= 0.06611728971388008 mape= 2.2050116990825335
# i= 13 mae= 0.02929714619363366 mape= 1.2387986510557054
# i= 14 mae= 0.025794708515542848 mape= 1.1727317815974247
# i= 15 mae= 0.0356348968088456 mape= 1.5385725459656294
# i= 16 mae= 0.08141374814433718 mape= 2.9891963201419998
# i= 17 mae= 0.04830647581359626 mape= 1.6080283607878623
# i= 18 mae= 0.07200187216095776 mape= 2.2638022075751927
# i= 19 mae= 0.051121370167480994 mape= 1.7395522908767194
# i= 20 mae= 0.03814364705616161 mape= 1.3707316887139998
# i= 21 mae= 0.0436226868568577 mape= 1.7573738014929774
# i= 22 mae= 0.04540121347026047 mape= 1.846013531828727
# i= 23 mae= 0.046711608340697396 mape= 1.9258787852404435
# i= 24 mae= 0.03265906166361626 mape= 1.3606181456454138
# i= 25 mae= 0.04988627152390124 mape= 2.770621172041145
# i= 26 mae= 0.04342418412776234 mape= 1.9283478421556584
# i= 27 mae= 0.03185114368128802 mape= 1.4671830175946876
# i= 28 mae= 0.035401691954437126 mape= 1.3982191511887796
# i= 29 mae= 0.03233183917635897 mape= 1.528568206068132
# i= 30 mae= 0.03593374153170382 mape= 2.2638475592915626
# i= 31 mae= 0.031081295650457943 mape= 2.140765418228645
# i= 32 mae= 0.03130760588727105 mape= 1.3407426629641446
# i= 33 mae= 0.039154223408441095 mape= 3.5327802973593614
# i= 34 mae= 0.032158480984337434 mape= 1.4003642799112541
# i= 35 mae= 0.03459911316475021 mape= 1.464460892690886
# i= 36 mae= 0.03543168441867777 mape= 1.5678992881913076
# i= 37 mae= 0.025308948397637965 mape= 1.1668123327451871
# i= 38 mae= 0.0511944726270017 mape= 3.105872787172515
# i= 39 mae= 0.03927600994332666 mape= 1.7443578523333059
# i= 40 mae= 0.07104499290942685 mape= 2.8045892092985873
# i= 41 mae= 0.03707828490259524 mape= 1.242691005728691
# i= 42 mae= 0.1542503834854299 mape= 6.882842045873034
    energy_cost_milp = 0
    for j in range(24):
        energy_cost_model += total_hvac_energy[i][j] * one_year_price[i*24 + j]
        energy_cost_milp += best_energy_testing[i][j] * one_year_price[i*24 + j]
    mae1 = np.fabs(energy_cost_milp - energy_cost_model)
    mape1 = np.fabs(energy_cost_milp - energy_cost_model) / energy_cost_milp * 100
    print("i=",i,"milp =",energy_cost_milp,"model=", energy_cost_model, "mae=",mae1, "mape=",mape1)
# Out:
# i= 0 milp = [128.21770793] model= [128.28427533] mae= [0.0665674] mape= [0.05191748]
# i= 1 milp = [121.7736094] model= [121.33086554] mae= [0.44274387] mape= [0.36357949]
# i= 2 milp = [111.79494807] model= [112.8545709] mae= [1.05962283] mape= [0.94782711]
# i= 3 milp = [128.63497068] model= [127.59237421] mae= [1.04259647] mape= [0.8105078]
# i= 4 milp = [164.72386835] model= [165.0762947] mae= [0.35242636] mape= [0.21394978]
# i= 5 milp = [143.76466221] model= [142.58392678] mae= [1.18073542] mape= [0.82129739]
# i= 6 milp = [123.88192839] model= [124.28307973] mae= [0.40115133] mape= [0.32381748]
# i= 7 milp = [108.66476472] model= [108.59256198] mae= [0.07220274] mape= [0.0664454]
# i= 8 milp = [83.78098534] model= [85.61907994] mae= [1.8380946] mape= [2.19392813]
# i= 9 milp = [89.48939393] model= [92.0249517] mae= [2.53555777] mape= [2.8333612]
# i= 10 milp = [154.5102354] model= [150.69023366] mae= [3.82000173] mape= [2.47232924]
# i= 11 milp = [175.86134258] model= [175.93652676] mae= [0.07518418] mape= [0.04275197]
# i= 12 milp = [177.63862339] model= [174.49749025] mae= [3.14113314] mape= [1.76827149]
# i= 13 milp = [158.18699253] model= [159.20078128] mae= [1.01378875] mape= [0.64087997]
# i= 14 milp = [123.96415341] model= [124.82615637] mae= [0.86200296] mape= [0.6953647]
# i= 15 milp = [123.28020931] model= [124.70853597] mae= [1.42832666] mape= [1.15860175]
# i= 16 milp = [134.99280297] model= [131.62299044] mae= [3.36981252] mape= [2.49629051]
# i= 17 milp = [182.60167433] model= [180.6993085] mae= [1.90236583] mape= [1.04181182]
# i= 18 milp = [210.33885798] model= [215.08512536] mae= [4.74626738] mape= [2.25648624]
# i= 19 milp = [183.09340933] model= [182.3953862] mae= [0.69802313] mape= [0.38123881]
# i= 20 milp = [154.74081013] model= [153.6650724] mae= [1.07573773] mape= [0.69518683]
# i= 21 milp = [138.43688455] model= [136.5950113] mae= [1.84187325] mape= [1.33047869]
# i= 22 milp = [128.78835504] model= [127.65022106] mae= [1.13813398] mape= [0.88372429]
# i= 23 milp = [131.2652753] model= [129.66638489] mae= [1.59889041] mape= [1.21806045]
# i= 24 milp = [106.61725534] model= [106.40265371] mae= [0.21460162] mape= [0.20128226]
# i= 25 milp = [96.30739898] model= [99.20159354] mae= [2.89419456] mape= [3.00516325]
# i= 26 milp = [129.33551111] model= [129.83694394] mae= [0.50143283] mape= [0.38769927]
# i= 27 milp = [125.4511308] model= [125.22407865] mae= [0.22705214] mape= [0.18098852]
# i= 28 milp = [137.10612859] model= [137.50666641] mae= [0.40053782] mape= [0.29213706]
# i= 29 milp = [108.99523153] model= [107.62631146] mae= [1.36892007] mape= [1.25594492]
# i= 30 milp = [71.95767817] model= [73.66356539] mae= [1.70588722] mape= [2.3706813]
# i= 31 milp = [59.19776369] model= [60.34889833] mae= [1.15113464] mape= [1.94455765]
# i= 32 milp = [101.76423133] model= [101.10435521] mae= [0.65987613] mape= [0.64843621]
# i= 33 milp = [61.49875373] model= [63.45107801] mae= [1.95232428] mape= [3.17457536]
# i= 34 milp = [107.46458884] model= [108.64376421] mae= [1.17917537] mape= [1.09726877]
# i= 35 milp = [127.52832376] model= [127.6234353] mae= [0.09511154] mape= [0.07458071]
# i= 36 milp = [117.95956133] model= [117.79362586] mae= [0.16593547] mape= [0.14067149]
# i= 37 milp = [98.64583042] model= [98.45252174] mae= [0.19330868] mape= [0.19596234]
# i= 38 milp = [73.5280812] model= [75.87578188] mae= [2.34770068] mape= [3.19293071]
# i= 39 milp = [111.94670256] model= [112.05171008] mae= [0.10500752] mape= [0.09380135]
# i= 40 milp = [135.58815417] model= [132.105918] mae= [3.48223617] mape= [2.56824513]
# i= 41 milp = [173.20201641] model= [172.06868161] mae= [1.1333348] mape= [0.65434273]
# i= 42 milp = [179.67923795] model= [178.34026067] mae= [1.33897728] mape= [0.74520423]
# i= 43 milp = [217.61470364] model= [222.72101569] mae= [5.10631205] mape= [2.3464922]
# i= 44 milp = [182.20446155] model= [183.91000546] mae= [1.7055439] mape= [0.93606045]
# i= 45 milp = [130.88995385] model= [129.18652875] mae= [1.7034251] mape= [1.30141775]
# i= 46 milp = [115.61701285] model= [115.64343049] mae= [0.02641764] mape= [0.02284927]
# i= 47 milp = [107.39034138] model= [107.76343643] mae= [0.37309505] mape= [0.34741955]
# i= 48 milp = [157.40036195] model= [158.27919579] mae= [0.87883384] mape= [0.55834296]
# i= 49 milp = [99.72962056] model= [98.29974589] mae= [1.42987466] mape= [1.43375123]
# i= 50 milp = [46.94297715] model= [49.53904883] mae= [2.59607168] mape= [5.53026637]
# i= 51 milp = [75.37669506] model= [76.82093044] mae= [1.44423538] mape= [1.91602375]
# i= 52 milp = [91.1261098] model= [90.56265427] mae= [0.56345554] mape= [0.61832502]
# i= 53 milp = [108.51943196] model= [108.0828862] mae= [0.43654577] mape= [0.40227429]
# i= 54 milp = [97.52746157] model= [97.30087863] mae= [0.22658295] mape= [0.23232733]
# i= 55 milp = [110.15311684] model= [110.12717307] mae= [0.02594377] mape= [0.02355246]
# i= 56 milp = [129.5858362] model= [129.09422349] mae= [0.49161271] mape= [0.37937226]
# i= 57 milp = [123.2479719] model= [123.41241486] mae= [0.16444296] mape= [0.13342447]
# i= 58 milp = [67.17296305] model= [69.03580031] mae= [1.86283725] mape= [2.773195]
# i= 59 milp = [58.54123249] model= [57.87781443] mae= [0.66341807] mape= [1.13324923]
# i= 60 milp = [116.04285614] model= [116.36562604] mae= [0.3227699] mape= [0.27814715]
# i= 61 milp = [135.49718743] model= [132.31102839] mae= [3.18615904] mape= [2.35145769]
# i= 62 milp = [124.45546407] model= [122.66399928] mae= [1.79146479] mape= [1.43944246]
# i= 63 milp = [113.73501842] model= [113.18110109] mae= [0.55391733] mape= [0.48702443]
# i= 64 milp = [116.34432572] model= [115.91909112] mae= [0.42523461] mape= [0.36549664]
# i= 65 milp = [106.97874644] model= [107.00706797] mae= [0.02832153] mape= [0.02647397]
# i= 66 milp = [61.73613938] model= [62.38548448] mae= [0.64934509] mape= [1.05180709]
# i= 67 milp = [29.80904348] model= [28.33065012] mae= [1.47839336] mape= [4.95954645]
# i= 68 milp = [17.77800737] model= [19.63020799] mae= [1.85220061] mape= [10.4184939]
# i= 69 milp = [31.53295341] model= [31.28846375] mae= [0.24448966] mape= [0.77534654]
# i= 70 milp = [71.12537349] model= [73.690309] mae= [2.56493551] mape= [3.60621728]
# i= 71 milp = [70.05559166] model= [67.98979966] mae= [2.065792] mape= [2.9487896]
# i= 72 milp = [61.52957189] model= [64.27143355] mae= [2.74186165] mape= [4.45616891]
# i= 73 milp = [53.23554572] model= [55.60553603] mae= [2.36999031] mape= [4.45189447]
# i= 74 milp = [55.19110303] model= [57.23712813] mae= [2.0460251] mape= [3.70716472]
# i= 75 milp = [54.16758626] model= [55.47815902] mae= [1.31057276] mape= [2.41947788]
# i= 76 milp = [52.30143497] model= [52.61216948] mae= [0.31073451] mape= [0.59412235]
# i= 77 milp = [74.10572827] model= [74.73214132] mae= [0.62641305] mape= [0.84529639]
# i= 78 milp = [84.79400231] model= [82.34509505] mae= [2.44890726] mape= [2.88806661]
# i= 79 milp = [98.0542945] model= [97.47023224] mae= [0.58406226] mape= [0.59565189]
# i= 80 milp = [86.51894778] model= [85.58952032] mae= [0.92942745] mape= [1.07424729]
# i= 81 milp = [83.01298991] model= [82.95016294] mae= [0.06282697] mape= [0.0756833]
# i= 82 milp = [57.51372796] model= [58.27726429] mae= [0.76353633] mape= [1.32757231]
# i= 83 milp = [70.8241434] model= [71.35259609] mae= [0.52845269] mape= [0.74614766]
# i= 84 milp = [81.20926073] model= [78.67039952] mae= [2.53886121] mape= [3.12631982]
# i= 85 milp = [83.81402948] model= [81.97075317] mae= [1.84327631] mape= [2.19924554]
# i= 86 milp = [50.04101958] model= [47.99341869] mae= [2.04760089] mape= [4.09184487]
# i= 87 milp = [36.63459469] model= [35.42959336] mae= [1.20500134] mape= [3.28924435]
# i= 88 milp = [67.44241031] model= [65.5975521] mae= [1.8448582] mape= [2.73545711]
# i= 89 milp = [62.03020416] model= [60.54351851] mae= [1.48668565] mape= [2.39671248]
# i= 90 milp = [26.05408433] model= [23.49090512] mae= [2.56317921] mape= [9.83791709]

# %%
plt.plot(total_temperature,'r',label="actual")
#plt.plot(best_temperature_valid[43],'b',label="predict")
plt.show()

# %%
plt.plot(best_energy_testing[67],'r',label="actual")
plt.plot(total_hvac_energy[67],'g',label="actual")
plt.show()

# %%
#hvac_energy_model = np.array(total_hvac_energy)
#temperature_model = np.array(total_temperature)
#np.savetxt("datasets/hvac_energy_model_2.csv", hvac_energy_model, delimiter=";")
#np.savetxt("datasets/temperature_model_2.csv", temperature_model, delimiter=";")
